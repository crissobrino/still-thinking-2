# %% [markdown]
# # Evaluation Prompts
# # Review and edit the test queries and ground truths used in `evaluate_automated.py`.

# %%
import json
import pandas as pd
from pathlib import Path

data = json.loads((Path("test_queries.json")).read_text())["queries"]
df = pd.DataFrame(data)[["type", "query", "ground_truth"]]

pd.set_option("display.max_colwidth", None)
df.style.set_properties(**{"text-align": "left", "white-space": "pre-wrap"})
# Out:
# <style type="text/css">
# #T_a5357_row0_col0, #T_a5357_row0_col1, #T_a5357_row0_col2, #T_a5357_row1_col0, #T_a5357_row1_col1, #T_a5357_row1_col2, #T_a5357_row2_col0, #T_a5357_row2_col1, #T_a5357_row2_col2, #T_a5357_row3_col0, #T_a5357_row3_col1, #T_a5357_row3_col2, #T_a5357_row4_col0, #T_a5357_row4_col1, #T_a5357_row4_col2, #T_a5357_row5_col0, #T_a5357_row5_col1, #T_a5357_row5_col2, #T_a5357_row6_col0, #T_a5357_row6_col1, #T_a5357_row6_col2, #T_a5357_row7_col0, #T_a5357_row7_col1, #T_a5357_row7_col2, #T_a5357_row8_col0, #T_a5357_row8_col1, #T_a5357_row8_col2 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_a5357">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5357_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_a5357_level0_col1" class="col_heading level0 col1" >query</th>
#       <th id="T_a5357_level0_col2" class="col_heading level0 col2" >ground_truth</th>
#     </tr>
#   </thead>
# ...
